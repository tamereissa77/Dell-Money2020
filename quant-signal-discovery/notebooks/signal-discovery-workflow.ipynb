# %% [markdown]
# # Quantitative Signal Discovery Agent developer example
#
# This notebook walks through an end-to-end signal discovery workflow for quantitative finance using the NeMo Agent Toolkit. The workflow uses LLMs to generate, code, and evaluate alpha signals.
#
# ## What You'll Learn
#
# By the end of this notebook, you will understand how to:
# - Set up a multi-step sequential workflow using NAT
# - Implement custom functions for signal generation, code generation, and evaluation
# - Use LLMs for signal design and code generation
# - Evaluate signal performance using rank IC metrics
# - Run complete end-to-end signal discovery workflows with optimization loops
#
# ## Workflow Overview
#
# This signal discovery workflow consists of three agents orchestrated by the NeMo Agent Toolkit:
#
# <div style="background-color: #e8f5e9; border-left: 6px solid #4caf50; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">🧩 Workflow Components</h4>
# <ul>
# <li><strong>Signal Agent</strong> — Uses an LLM to generate signal expressions from price-volume data and predefined operators</li>
# <li><strong>Code Agent</strong> — Converts signal expressions into executable Python code using operator implementations from <code>calculator.json</code></li>
# <li><strong>Eval Agent</strong> — Evaluates the predictive power of generated signals using Rank IC (backtesting) and provides optimization suggestions for iterative improvement</li>
# </ul>
# The default configuration uses <strong>nvidia/nemotron-3.5-lightning-30b-a3b</strong> for all three agents.
# </div>
#
# <div style="background-color: #fff3cd; border-left: 6px solid #ffc107; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">⚠️ Note</h4>
# This example demonstrates the capabilities of NeMo Agent Toolkit for automating quantitative research workflows. The generated signals should be thoroughly validated before use in production.
# </div>
#
# <div style="background-color: #e3f2fd; border-left: 6px solid #1976d2; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">☁️ Running on Brev?</h4>
# If you are deploying via a Brev launchable, run <a href="../brev/launchable-setup.ipynb"><code>brev/launchable-setup.ipynb</code></a> first — it clones this repo, installs <code>uv</code>, syncs dependencies, registers a <strong>Signal Discovery</strong> kernel, and downloads the dataset. Then come back here and select that kernel before running the cells below.
# </div>

# %% [markdown]
# ## Table of Contents
#
# - [0) Setup](#setup)
#   - [0.1) Prerequisites](#prereqs)
#   - [0.2) API Keys](#api-keys)
#   - [0.3) Installing Dependencies](#installing-deps)
#   - [0.4) Download Data](#download-data)
# - [1) Understanding Signal Discovery](#understanding-workflow)
#   - [1.1) What is Signal Discovery?](#what-is-signal-discovery)
#   - [1.2) Workflow Architecture](#workflow-architecture)
# - [2) Source Code Components](#source-code)
#   - [2.1) Signal Agent](#signal-agent)
#   - [2.2) Code Agent](#code-agent)
#   - [2.3) Eval Agent](#eval-agent) *(includes Rank IC utilities)*
#   - [2.4) Signal Discovery Optimization Workflow](#optimization-workflow)
#   - [2.5) Register Module](#register-module)
# - [3) Configuration](#configuration)
#   - [3.1) Workflow Configuration](#workflow-config)
#   - [3.2) Operator Templates](#operator-templates)
# - [4) Running the Workflow](#running-workflow)
# - [5) Interpreting Results](#interpreting-results)
#   - [5.1) Understanding Evaluation Metrics](#evaluation-metrics)
#   - [5.2) Analyzing Generated Signals](#analyzing-signals)
# - [6) Conclusion](#conclusion)
# - [7) Next Steps](#next-steps)

# %% [markdown]
# <h1 id="setup">0) Setup</h1>
#
# <h2 id="prereqs">0.1) Prerequisites</h2>
#
# <div style="background-color: #e8f4f8; border-left: 6px solid #0288d1; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">📋 Requirements</h4>
# <ul>
# <li><strong>Platform:</strong> Linux, macOS, or Windows</li>
# <li><strong>Python:</strong> version 3.11, 3.12, or 3.13</li>
# <li><strong>Package manager:</strong> uv</li>
# </ul>
# </div>

# %% [markdown]
# <h2 id="api-keys">0.2) API Keys</h2>
#
# <div style="background-color: #fff3cd; border-left: 6px solid #ffc107; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">🔑 NVIDIA API Key Required</h4>
# For this notebook, you will need an NVIDIA API key. Get yours from <a href="https://build.nvidia.com/settings/api-keys">build.nvidia.com</a>.
# </div>

# %%
import getpass
import os
from pathlib import Path

if "NVIDIA_API_KEY" not in os.environ:
    env_path = Path("../.env") if Path("../.env").exists() else Path(".env")
    if env_path.exists():
        for line in env_path.read_text().splitlines():
            if line.strip().startswith("NVIDIA_API_KEY="):
                os.environ["NVIDIA_API_KEY"] = line.split("=", 1)[1].strip().strip('"').strip("'")
                break

if "NVIDIA_API_KEY" not in os.environ:
    os.environ["NVIDIA_API_KEY"] = getpass.getpass("Enter your NVIDIA API key: ")

# %% [markdown]
# <h2 id="installing-deps">0.3) Installing Dependencies</h2>
#
# Sync the locked project environment from <code>uv.lock</code>:

# %%
# Sync the locked dependency graph. Do not use %pip install here; pip ignores uv.lock.
import os
import shutil
import subprocess
from pathlib import Path

project_root = Path.cwd()
if not (project_root / "pyproject.toml").exists() and (project_root.parent / "pyproject.toml").exists():
    project_root = project_root.parent
if not (project_root / "pyproject.toml").exists():
    raise FileNotFoundError("Could not locate pyproject.toml. Open this notebook from the repo or notebooks/ directory.")
if not shutil.which("uv"):
    raise RuntimeError("uv is required. Install it with: curl -LsSf https://astral.sh/uv/install.sh | sh")

subprocess.run(["uv", "sync", "--locked", "--extra", "test"], cwd=project_root, check=True)
os.chdir(project_root)
print(f"Synced locked dependencies from {project_root}")

# %% [markdown]
# <h2 id="download-data">0.4) Download Data</h2>
#
# <div style="background-color: #e8f4f8; border-left: 6px solid #0288d1; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">📥 S&P 500 Price-Volume Data</h4>
# The workflow requires price-volume data (Open, Close, High, Low, Volume) stored as CSV files in <code>src/signal_discovery_workflow/data/sp500/</code>. Use the script below to download fresh data from Yahoo Finance via <code>yfinance</code>.
# </div>
#
# <div style="background-color: #fff3cd; border-left: 6px solid #ffc107; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">⚠️ Disclaimer</h4>
# Each user is responsible for checking the content of datasets and the applicable licenses and determining if suitable for the intended use.
# </div>

# %%
from pathlib import Path
from signal_discovery_workflow.download_data import download_sp500_data

data_dir = Path("src/signal_discovery_workflow/data/sp500")
if not data_dir.exists() or not list(data_dir.glob("*.csv")):
    print("Data not found. Downloading S&P 500 data...")
    data = download_sp500_data(start="2012-01-01", end="2025-12-31")
else:
    import pandas as pd
    print("Data already exists. Loading from disk...")
    data = {f.stem: pd.read_csv(f, index_col=0, parse_dates=True) for f in data_dir.glob("*.csv")}

for field, df in data.items():
    print(f"{field}: {df.shape[0]} days x {df.shape[1]} stocks")

# %% [markdown]
# <h1 id="understanding-workflow">1) Understanding Signal Discovery</h1>
#
# <h2 id="what-is-signal-discovery">1.1) What is Signal Discovery?</h2>
#
# Signal discovery is the process of finding quantitative signals that have predictive power for future stock returns. In quantitative finance, signals are numerical characteristics of stocks that can be used to:
#
# - **Predict returns**: Signals with high Information Coefficient (IC) can help forecast which stocks will outperform
# - **Construct portfolios**: Long stocks with favorable signal values, short those with unfavorable values
# - **Manage risk**: Understand exposures to different sources of returns
#
# Traditional signal research is labor-intensive, requiring researchers to:
# 1. Formulate hypotheses about what might predict returns
# 2. Implement the signal calculation in code
# 3. Backtest the signal's performance
# 4. Iterate based on results
#
# This workflow automates that loop with LLM-assisted signal generation and code generation.

# %% [markdown]
# <h2 id="workflow-architecture">1.2) Workflow Architecture</h2>
#
# ![Workflow Architecture](images/workflow-architecture.png)
#
# <div style="background-color: #f3e5f5; border-left: 6px solid #9c27b0; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">💡 Closed-Loop Optimization</h4>
# The workflow is orchestrated by the <strong>NeMo Agent Toolkit</strong> and uses a closed-loop optimization approach:
# <ol>
# <li><strong>Signal Agent</strong> receives price-volume data and operators, then generates signal expressions using the LLM</li>
# <li><strong>Code Agent</strong> converts signal expressions into executable Python code and includes the required operator implementations from <code>calculator.json</code></li>
# <li><strong>Eval Agent</strong> evaluates the signal's predictive power via backtesting (Rank IC)
# <ul>
# <li>If IC meets threshold → Accept and produce <strong>backtesting results</strong></li>
# <li>If IC is poor → Generate <strong>optimization suggestions</strong> and feed them back to the Signal Agent for a new iteration</li>
# </ul>
# </li>
# </ol>
# </div>

# %% [markdown]
# <h1 id="source-code">2) Source Code Components</h1>
#
# Below we load and display the source code for each component of the signal discovery workflow. Use `%load` to load the Python source files.
#
# <h2 id="signal-agent">2.1) Signal Agent</h2>
#
# <div style="background-color: #e8f5e9; border-left: 6px solid #4caf50; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">📊 Signal Agent</h4>
# Uses the configured NIM model to generate quantitative signal expressions based on available price-volume data (Open, Close, High, Low, Volume) and predefined operators.
# <ul>
# <li><strong>Input:</strong> Signal type request (e.g., "momentum signals"), price-volume data fields, operator definitions</li>
# <li><strong>Output:</strong> Signal expressions in JSON format with names, formulas, and economic intuition</li>
# </ul>
# </div>

# %%
# %load src/signal_discovery_workflow/signal_generator.py

# %% [markdown]
# <h2 id="code-agent">2.2) Code Agent</h2>
#
# <div style="background-color: #e3f2fd; border-left: 6px solid #1976d2; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">💻 Code Agent</h4>
# Converts signal expressions into executable Python code. The LLM writes the signal function while the workflow includes the required operator implementations from <code>calculator.json</code>.
# <ul>
# <li><strong>Input:</strong> Signal expressions (JSON) from the Signal Agent</li>
# <li><strong>Output:</strong> Executable Python code implementing the signal calculations</li>
# <li><strong>Operators:</strong> required implementations are loaded from <code>calculator.json</code></li>
# </ul>
# </div>

# %%
# %load src/signal_discovery_workflow/signal_code_generator.py

# %% [markdown]
# <h2 id="eval-agent">2.3) Eval Agent</h2>
#
# <div style="background-color: #fff3e0; border-left: 6px solid #ff9800; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">📈 Eval Agent</h4>
# Performs backtesting by computing the Spearman correlation (Rank IC) between signal values and forward stock returns to measure predictive power.
# <ul>
# <li><strong>Input:</strong> Executable code from the Code Agent</li>
# <li><strong>Output:</strong> Backtesting results (IC metrics) and optimization suggestions</li>
# <li><strong>Accept criteria:</strong> |IC| ≥ threshold and p-value ≤ significance level</li>
# <li><strong>Feedback loop:</strong> When signals fall below threshold, generates optimization suggestions for the Signal Agent</li>
# </ul>
# </div>

# %%
# %load src/signal_discovery_workflow/signal_evaluator.py

# %% [markdown]
# <h2 id="optimization-workflow">2.4) Signal Discovery Optimization Workflow</h2>
#
# <div style="background-color: #f9f9f9; border: 2px solid #ddd; padding: 20px; border-radius: 8px; margin: 20px 0;">
# <h4 style="margin-top: 0;">🔄 NeMo Agent Toolkit Orchestration</h4>
# The Signal Discovery Optimization Workflow uses the NeMo Agent Toolkit to orchestrate the closed-loop pipeline. It composes the Signal Agent, Code Agent, and Eval Agent: generate signal expressions, convert them to executable code, backtest performance, and feed optimization suggestions into the next iteration.
# <pre style="background-color: #f5f5f5; padding: 10px; border-radius: 3px; margin: 10px 0;">
# Signal Agent -> signal expressions -> Code Agent -> executable code -> Eval Agent
#       ↑                                                                    |
#       └──────────── optimization suggestions ←─────────────────────────────┘
# </pre>
# </div>

# %%
# %load src/signal_discovery_workflow/signal_discovery_optimization_workflow.py

# %% [markdown]
# <h2 id="register-module">2.5) Register Module</h2>
#
# The register module imports all components to make them available to the NeMo Agent Toolkit.

# %%
# %load src/signal_discovery_workflow/register.py

# %% [markdown]
# <h1 id="configuration">3) Configuration</h1>
#
# <h2 id="workflow-config">3.1) Workflow Configuration</h2>
#
# <div style="background-color: #e8f4f8; border-left: 6px solid #0288d1; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">⚙️ Workflow Configuration</h4>
# The workflow configuration defines how the signal optimization agent operates. It specifies:
# <ul>
# <li><strong>LLM assignments</strong> — Which model powers each agent (Signal, Code, Eval)</li>
# <li><strong>Temperature settings</strong> — Higher for creative signal generation, lower for precise code generation</li>
# <li><strong>Acceptance criteria</strong> — IC threshold and p-value thresholds for signal quality</li>
# <li><strong>Iteration limits</strong> — Maximum optimization attempts before accepting best result</li>
# </ul>
# </div>
#
# <div style="background-color: #fff3cd; border-left: 6px solid #ffc107; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">⚠️ LLM Base URL</h4>
# The <code>base_url</code> for the LLMs depends on your API key:
# <ul>
# <li><code>https://integrate.api.nvidia.com/v1/</code> — for keys from <a href="https://build.nvidia.com">build.nvidia.com</a></li>
# <li><code>https://inference-api.nvidia.com/v1/</code> — for NVIDIA internal or enterprise API keys</li>
# </ul>
# Update the <code>base_url</code> field in <code>configs/config-optimization.yml</code> to match your API key type.
# </div>

# %%
# Display the configuration file
with open("configs/config-optimization.yml", "r") as f:
    print(f.read())

# %% [markdown]
# <div style="background-color: #f3e5f5; border-left: 6px solid #9c27b0; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">💡 Configuration Parameters Explained</h4>
# <table style="width: 100%; border-collapse: collapse;">
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>signal_generator_llm</code></td><td style="padding: 8px;">LLM for generating signal expressions (higher temperature for creativity)</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>code_generator_llm</code></td><td style="padding: 8px;">LLM for converting expressions to executable code (lower temperature for precision)</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>optimization_advisor_llm</code></td><td style="padding: 8px;">LLM for generating optimization feedback (balanced temperature)</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>ic_threshold</code></td><td style="padding: 8px;">Minimum absolute IC value to accept a signal (e.g., 0.02 = 2%)</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>p_value_threshold</code></td><td style="padding: 8px;">Maximum p-value for statistical significance (e.g., 0.05 = 5%)</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>max_iterations</code></td><td style="padding: 8px;">Maximum number of optimization iterations before accepting best result</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>num_signals</code></td><td style="padding: 8px;">Number of signals to generate per iteration</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><code>forward_periods</code></td><td style="padding: 8px;">Number of days for forward return calculation (e.g., 5 = weekly)</td></tr>
# <tr><td style="padding: 8px;"><code>save_results</code></td><td style="padding: 8px;">Whether to save successful signals to disk</td></tr>
# </table>
# </div>

# %% [markdown]
# <h2 id="operator-templates">3.2) Operator Templates</h2>
#
# <div style="background-color: #e8f5e9; border-left: 6px solid #4caf50; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">🧮 Operator Templates</h4>
# The workflow uses predefined operators from <code>calculator.json</code>. These operators are the building blocks the Signal Agent uses to compose signal expressions, and their implementations are included in generated code.
# </div>

# %%
import json
from pathlib import Path

# Load and display sample operators
template_path = Path("src/signal_discovery_workflow/template/calculator.json")
with open(template_path, "r") as f:
    operators = json.load(f)

print(f"Total operators available: {len(operators)}\n")
print("Sample operators:")
print("-" * 60)
for op in operators[:10]:
    print(f"\n{op['name']}:")
    print(f"  Signature: {op['signature']}")
    print(f"  Meaning: {op['meanings'][:80]}...")

# %% [markdown]
# <h1 id="running-workflow">4) Running the Workflow</h1>
#
# <div style="background-color: #e8f5e9; border-left: 6px solid #4caf50; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">🚀 Running the Workflow</h4>
# Now we run the workflow and see the generated signals. The workflow will:
# <ol>
# <li>Start the NeMo Agent Toolkit orchestration</li>
# <li>Load price-volume data (Open, Close, High, Low, Volume)</li>
# <li>Run the Signal Agent → Code Agent → Eval Agent pipeline</li>
# <li>Iterate until IC threshold is met or max iterations reached</li>
# <li>Save accepted signals to disk</li>
# </ol>
# </div>

# %% [markdown]
# Phoenix is an open-source observability platform that captures and visualizes traces from your agent. It runs as a local web server that collects trace data and provides an interactive UI for analysis.
# <div style="background-color: #fff3cd; border-left: 6px solid #ffc107; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">🚀 Production vs. Notebook Setup</h4>
# <strong>In production,</strong> you'd simply run in a terminal:
# <pre style="background-color: #f5f5f5; padding: 10px; border-radius: 3px; margin: 10px 0;">
# phoenix serve
# </pre>
# <strong>In Jupyter,</strong> you'll use <code>subprocess</code> to start Phoenix in the background.
# </div>

# %%
import subprocess
import time
import sys

# Start Phoenix 
phoenix_process = subprocess.Popen(
    ["phoenix", "serve"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

# Read initial output
print("Starting Phoenix...")
start_time = time.time()
while time.time() - start_time < 3:
    line = phoenix_process.stdout.readline()
    if line:
        print(line.strip())

print("\n✅ Phoenix is running silently in the background!")

# %% [markdown]
# <div style="background-color: #f3e5f5; border-left: 6px solid #9c27b0; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">💡 What Phoenix Does</h4>
# <ul>
# <li><strong>Captures traces</strong> - Every agent decision, tool call, and LLM interaction</li>
# <li><strong>Stores telemetry</strong> - Timing data, token usage, success/failure status</li>
# <li><strong>Provides visualization</strong> - Interactive UI to explore traces and find patterns</li>
# <li><strong>Runs locally</strong> - Your data never leaves your machine (default port: 6006)</li>
# </ul>
# </div>
#
# ## Access Phoenix UI
#
# If the button below does not work, manually open <a href="http://localhost:6006">http://localhost:6006</a> in your browser.

# %%
from IPython.display import HTML, display

html = """
<div style="padding: 15px; background-color: #e8f4f8; border-radius: 8px; margin: 10px 0;">
    <h4 style="margin: 0 0 10px 0;">🔍 Phoenix Observability Dashboard</h4>
    <p>Click the button to open Phoenix (it will auto-detect the correct URL):</p>
    <button onclick="
        var url = window.location.origin.replace(/p\\d+/, 'p6006');
        window.open(url, '_blank');
    " style="padding: 10px 20px; background-color: #0066cc; color: white; border: none; border-radius: 4px; cursor: pointer; font-size: 14px;">
        🚀 Open Phoenix UI
    </button>
    <p style="margin-top: 10px; font-size: 12px; color: #666;">
        If the button doesn't work, open <a href="http://localhost:6006">http://localhost:6006</a> directly
    </p>
</div>
"""

display(HTML(html))

# %% [markdown]
# ## Phoenix Configuration
# To enable Phoenix tracing, you add a `telemetry section` to your NAT config. This tells NAT where to send trace data.
# <div style="background-color: #f9f9f9; border: 2px solid #ddd; padding: 20px; border-radius: 8px; margin: 20px 0;">
# <h4 style="text-align: center;">Phoenix Configuration Structure</h4>
# <pre style="background-color: #f5f5f5; padding: 15px; border-radius: 5px; margin: 10px 0;">
# general:                                              # Global workflow settings
#   telemetry:                                          # Monitoring and metrics
#     tracing:                                          # Distributed tracing config
#       phoenix:                                        # Phoenix-specific settings
#         _type: phoenix                                # Use Phoenix provider
#         endpoint: http://localhost:6006/v1/traces     # Where to send data
#         project: signal_discovery_workflow               # Project name in UI
# </pre>
# </div>
# <div style="background-color: #f3e5f5; border-left: 6px solid #9c27b0; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">💡 Key Configuration Fields</h4>
# <ul>
# <li><strong>endpoint</strong> - Phoenix trace collector URL (must match where Phoenix is running)</li>
# <li><strong>project</strong> - Groups traces together in the UI. Use different names to compare versions (e.g., "baseline" vs. "optimized")</li>
# <li><strong>_type: phoenix</strong> - NAT supports multiple tracing backends; this specifies Phoenix</li>
# </ul>
# </div>
# The config file at `configs/config-optimization.yml` already includes this telemetry section.

# %%
# Generate momentum signals
# !uv run --locked nat run --config_file configs/config-optimization.yml --input "momentum signals"

# %% [markdown]
# ### Running with Different Signal Types
#
# The same workflow handles any signal category — just change the `--input` string. The Signal Agent will generate completely different formulas appropriate for each category.
#
# ```bash
# # Volatility signals (e.g., rolling standard deviation, range-based)
# nat run --config_file configs/config-optimization.yml --input "volatility signals"
#
# # Mean-reversion signals (e.g., distance from moving average)
# nat run --config_file configs/config-optimization.yml --input "mean-reversion signals"
#
# # Volume-price divergence signals (e.g., volume relative to price moves)
# nat run --config_file configs/config-optimization.yml --input "volume price divergence signals"
# ```
#
# You can run any of these from a terminal in the project root, or invoke them from this notebook with `!nat run ...` if you want to keep iterating interactively.

# %% [markdown]
# <h1 id="interpreting-results">5) Interpreting Results</h1>
#
# <h2 id="evaluation-metrics">5.1) Understanding Evaluation Metrics</h2>
#
# <div style="background-color: #e3f2fd; border-left: 6px solid #1976d2; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">📊 Backtesting Metrics</h4>
# The Eval Agent evaluates signals using several key metrics:
# <table style="width: 100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #bbdefb;"><th style="padding: 8px; text-align: left;">Metric</th><th style="padding: 8px; text-align: left;">Description</th><th style="padding: 8px; text-align: left;">Good Value</th></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><strong>Mean IC</strong></td><td style="padding: 8px;">Average Spearman correlation between signal and forward returns</td><td style="padding: 8px;">|IC| > 0.03</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><strong>IC Std</strong></td><td style="padding: 8px;">Standard deviation of IC values</td><td style="padding: 8px;">Lower is more consistent</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><strong>IC IR</strong></td><td style="padding: 8px;">Information Ratio = Mean IC / IC Std</td><td style="padding: 8px;">> 0.5 is good</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><strong>T-statistic</strong></td><td style="padding: 8px;">Statistical significance of mean IC</td><td style="padding: 8px;">|t| > 2 is significant</td></tr>
# <tr style="border-bottom: 1px solid #ddd;"><td style="padding: 8px;"><strong>P-value</strong></td><td style="padding: 8px;">Probability IC is different from zero</td><td style="padding: 8px;">< 0.05 is significant</td></tr>
# <tr><td style="padding: 8px;"><strong>Positive IC Ratio</strong></td><td style="padding: 8px;">Fraction of periods with positive IC</td><td style="padding: 8px;">> 0.55 is good</td></tr>
# </table>
# </div>
#
# <div style="background-color: #f9f9f9; border: 2px solid #ddd; padding: 20px; border-radius: 8px; margin: 20px 0;">
# <h4 style="margin-top: 0;">📈 Rank IC Value Interpretation</h4>
# <table style="width: 100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #ffcdd2;"><td style="padding: 10px; width: 20%;"><strong>< 0.02</strong></td><td style="padding: 10px;"><strong>Weak/Noise:</strong> Very little predictive power. May still be useful in a multi-signal model, but not a strong standalone signal.</td></tr>
# <tr style="background-color: #c8e6c9;"><td style="padding: 10px;"><strong>0.02 – 0.05</strong></td><td style="padding: 10px;"><strong>Good/Standard:</strong> Target range for institutional-grade signals (Value, Quality). Generates consistent Alpha across a large stock universe.</td></tr>
# <tr style="background-color: #a5d6a7;"><td style="padding: 10px;"><strong>0.05 – 0.15</strong></td><td style="padding: 10px;"><strong>Strong:</strong> Very high-quality signal, typical of short-term Momentum or specialized High-Frequency signals.</td></tr>
# <tr style="background-color: #fff3cd;"><td style="padding: 10px;"><strong>> 0.15</strong></td><td style="padding: 10px;"><strong>Exceptional/Suspicious:</strong> Rare in live markets. Check for look-ahead bias or overfitting.</td></tr>
# </table>
# </div>

# %% [markdown]
# <h2 id="analyzing-signals">5.2) Analyzing Generated Signals</h2>
#
# The cell below automatically loads the most recent signal output and displays the generated signal expressions, which signal was selected for evaluation, and the corresponding IC metrics.

# %%
import json
import re
from pathlib import Path

def _match_signal_name(func_name: str, display_name: str) -> bool:
    """Check if a Python function name corresponds to a signal's display name."""
    func_tokens = set(func_name.lower().replace("signal_", "").split("_"))
    display_tokens = set(re.split(r"[\s\-_]+", display_name.lower()))
    return func_tokens.issubset(display_tokens)

def _parse_signal_expressions(signal_description: str) -> list:
    """Extract the signal JSON array from the LLM's signal_description output."""
    match = re.search(r"```json\s*(\[.*?\])\s*```", signal_description, re.DOTALL)
    if match:
        try:
            return json.loads(match.group(1))
        except json.JSONDecodeError:
            pass
    try:
        return json.loads(signal_description)
    except (json.JSONDecodeError, TypeError):
        return []

def interpret_ic_results(result_path: str):
    """
    Interpret the IC evaluation results from a saved signal JSON file.
    """
    with open(result_path, "r", encoding="utf-8") as f:
        result = json.load(f)
    
    print("=" * 60)
    print("SIGNAL EVALUATION RESULTS")
    print("=" * 60)
    
    print(f"\nTimestamp: {result.get('timestamp', 'N/A')}")
    print(f"Iteration: {result.get('iteration', 'N/A')}")
    
    selected = result.get("selected_signal", "")
    
    signals = _parse_signal_expressions(result.get("signal_description", ""))
    if signals:
        print(f"\nGenerated Signals ({len(signals)}):")
        print("-" * 40)
        for i, signal in enumerate(signals, 1):
            name = signal.get('name', 'N/A')
            is_selected = selected and _match_signal_name(selected, name)
            marker = " << SELECTED" if is_selected else ""
            print(f"\n  Signal {i}: {name}{marker}")
            print(f"    Formula:    {signal.get('formula', 'N/A')}")
            print(f"    Meaning:    {signal.get('meaning', 'N/A')}")
            print(f"    Category:   {signal.get('category', 'N/A')}")
            print(f"    Data fields: {', '.join(signal.get('data_fields_used', []))}")
            print(f"    Operators:   {', '.join(signal.get('operators_used', []))}")
            print(f"    Lookback:    {signal.get('lookback_periods', 'N/A')}")
    
    metrics = result.get("evaluation_metrics", {})
    if metrics:
        metric_label = f"Evaluation Metrics (on: {selected})" if selected else "Evaluation Metrics"
        print(f"\n{metric_label}:")
        print("-" * 40)
        print(f"  Mean IC: {metrics.get('mean_ic', 'N/A'):.4f}" if metrics.get('mean_ic') is not None else "  Mean IC: N/A")
        print(f"  IC Std: {metrics.get('ic_std', 'N/A'):.4f}" if metrics.get('ic_std') is not None else "  IC Std: N/A")
        print(f"  IC IR: {metrics.get('ic_ir', 'N/A'):.4f}" if metrics.get('ic_ir') is not None else "  IC IR: N/A")
        print(f"  T-stat: {metrics.get('t_stat', 'N/A'):.4f}" if metrics.get('t_stat') is not None else "  T-stat: N/A")
        print(f"  P-value: {metrics.get('p_value', 'N/A'):.6f}" if metrics.get('p_value') is not None else "  P-value: N/A")
        print(f"  Num Periods: {metrics.get('num_periods', 'N/A')}")
        print(f"  Positive IC Ratio: {metrics.get('positive_ic_ratio', 'N/A'):.2%}" if metrics.get('positive_ic_ratio') is not None else "  Positive IC Ratio: N/A")
        
        percentiles = metrics.get("ic_percentiles", {})
        if percentiles:
            print("\n  IC Percentiles:")
            for pct, val in percentiles.items():
                print(f"    {pct}: {val:.4f}")
    
    signal_code = result.get("signal_code", "")
    if signal_code:
        print("\nSignal Code:")
        print("-" * 40)
        print(signal_code)

# Automatically pick the most recent output file
output_dir = Path("src/signal_discovery_workflow/output")
signal_files = sorted(output_dir.glob("signal_*.json"), key=lambda f: f.stat().st_mtime, reverse=True)
if signal_files:
    print(f"Showing results for: {signal_files[0].name}\n")
    interpret_ic_results(str(signal_files[0]))
else:
    print("No signal output files found. Run the workflow first!")

# %% [markdown]
# <h1 id="conclusion">6) Conclusion</h1>
#
# <div style="background-color: #fff8e1; border-left: 6px solid #ffa000; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">⚠️ About This Example Run</h4>
# <p>
# The results shown in this notebook are from a <strong>demonstration run</strong> with <code>max_iterations: 2</code>. This means the optimization loop stops after at most <strong>two iterations</strong> — if the generated signal does not meet the IC threshold on the first attempt, the workflow collects optimization feedback and tries once more before accepting the best result found so far (a "best effort" outcome).
# </p>
# <p>
# In practice, you can increase <code>max_iterations</code> in the workflow configuration to allow the agent more attempts to discover higher-quality signals. More iterations give the LLM additional chances to refine its signal formulas based on evaluation feedback, which often leads to stronger signals. However, each iteration incurs additional LLM inference cost and runtime, so the right setting depends on your time and compute budget.
# </p>
# </div>

# %% [markdown]
# <h1 id="next-steps">7) Next Steps</h1>
#
# <div style="background-color: #e8f5e9; border-left: 6px solid #4caf50; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">🔮 Ideas for Extending the Workflow</h4>
# <ol>
# <li><strong>Add more operators</strong> — Extend <code>calculator.json</code> with additional technical indicators</li>
# <li><strong>Use different data</strong> — Replace SP500 data with your own stock universe</li>
# <li><strong>Customize evaluation</strong> — Modify IC thresholds or add additional metrics like turnover</li>
# <li><strong>Add more data fields</strong> — Include fundamental data like earnings, book value, etc.</li>
# <li><strong>Build signal portfolios</strong> — Use accepted signals to construct trading strategies</li>
# </ol>
# </div>
#
# <div style="background-color: #e3f2fd; border-left: 6px solid #1976d2; padding: 15px; margin: 15px 0;">
# <h4 style="margin-top: 0;">📚 Additional Resources</h4>
# <ul>
# <li><a href="https://docs.nvidia.com/nemo-agent-toolkit/">NeMo Agent Toolkit Documentation</a></li>
# <li><a href="https://arize.com/docs/phoenix">Arize Phoenix Documentation</a></li>
# </ul>
# </div>
